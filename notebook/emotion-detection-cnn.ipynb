png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2900.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1896.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1103.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im638.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im173.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2017.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1437.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im702.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1237.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2520.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2664.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im323.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2737.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im425.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2536.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im371.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im354.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im798.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1234.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im57.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2774.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im403.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1449.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2275.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1188.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2103.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1215.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1018.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im776.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1668.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im13.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1823.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2496.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2817.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2692.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1570.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2309.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2899.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2573.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im224.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2417.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1890.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2621.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im864.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im785.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2374.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2132.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im375.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im92.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im430.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im153.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im956.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1819.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im932.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1161.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im1978.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2400.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im326.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im391.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im2998.png
# /kaggle/input/emotion-detection/emotion-detection/train/happy/im506.png

# %% [markdown]
# # 1| Import our important libraries

# %%
# libraries for system
import os
import time
import shutil
import pathlib
import itertools
from PIL import Image


# import data handling tools
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report



#import DL libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# # 2| Data preprocessing

# %%
train_dir = '/kaggle/input/emotion-detection/emotion-detection/train'
filepaths = []
labels = []

folds = os.listdir(train_dir)
for fold in folds:
    foldpath = os.path.join(train_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        filepaths.append(fpath)
        labels.append(fold)

# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name= 'filepaths')
Lseries = pd.Series(labels, name='labels')
train_df = pd.concat([Fseries, Lseries], axis= 1)

# %%
train_df
# Out:
#                                                filepaths   labels
# 0      /kaggle/input/emotion-detection/emotion-detect...  fearful
# 1      /kaggle/input/emotion-detection/emotion-detect...  fearful
# 2      /kaggle/input/emotion-detection/emotion-detect...  fearful
# 3      /kaggle/input/emotion-detection/emotion-detect...  fearful
# 4      /kaggle/input/emotion-detection/emotion-detect...  fearful
# ...                                                  ...      ...
# 12937  /kaggle/input/emotion-detection/emotion-detect...    happy
# 12938  /kaggle/input/emotion-detection/emotion-detect...    happy
# 12939  /kaggle/input/emotion-detection/emotion-detect...    happy
# 12940  /kaggle/input/emotion-detection/emotion-detect...    happy
# 12941  /kaggle/input/emotion-detection/emotion-detect...    happy
#
# [12942 rows x 2 columns]

# %%
# Generate  test data paths with labels
test_dir = '/kaggle/input/emotion-detection/emotion-detection/test'
filepaths = []
labels = []

folds = os.listdir(test_dir)
for fold in folds:
    foldpath = os.path.join(test_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        filepaths.append(fpath)
        labels.append(fold)

# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name= 'filepaths')
Lseries = pd.Series(labels, name='labels')
test_df = pd.concat([Fseries, Lseries], axis= 1)

# %%
test_df
# Out:
#                                               filepaths   labels
# 0     /kaggle/input/emotion-detection/emotion-detect...  fearful
# 1     /kaggle/input/emotion-detection/emotion-detect...  fearful
# 2     /kaggle/input/emotion-detection/emotion-detect...  fearful
# 3     /kaggle/input/emotion-detection/emotion-detect...  fearful
# 4     /kaggle/input/emotion-detection/emotion-detect...  fearful
# ...                                                 ...      ...
# 7173  /kaggle/input/emotion-detection/emotion-detect...    happy
# 7174  /kaggle/input/emotion-detection/emotion-detect...    happy
# 7175  /kaggle/input/emotion-detection/emotion-detect...    happy
# 7176  /kaggle/input/emotion-detection/emotion-detect...    happy
# 7177  /kaggle/input/emotion-detection/emotion-detect...    happy
#
# [7178 rows x 2 columns]

# %% [markdown]
# # 3| Splitting the dataframe into train , valid and test

# %%
# valid and test dataframe
valid_df, test_df = train_test_split(test_df,  train_size= 0.6, shuffle= True, random_state= 123)

# %% [markdown]
# # 4| Image Data Generator

# %%
# crobed image size
batch_size = 16
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()
train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size= batch_size)
# Out:
# Found 12942 validated image filenames belonging to 7 classes.
# Found 4306 validated image filenames belonging to 7 classes.
# Found 2872 validated image filenames belonging to 7 classes.

# %% [markdown]
# # 5| Showing sample from our train data

# %%
g_dict = train_gen.class_indices      # defines dictionary {'class': index}
classes = list(g_dict.keys())       # defines list of dictionary's kays (classes), classes names : string
images, labels = next(train_gen)      # get a batch size samples from the generator

plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255       # scales data to range (0 - 255)
    plt.imshow(image)
    index = np.argmax(labels[i])  # get image index
    class_name = classes[index]   # get class of image
    plt.title(class_name, color= 'blue', fontsize= 12)
    plt.axis('off')
plt.show()

# %% [markdown]
# # 6| Model structure

# %%
#Create Model Structure
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
class_count = len(list(train_gen.class_indices.keys())) # to define number of classes in dense layer

# create pre-trained model (you can built on pretrained model such as :  efficientnet, VGG , Resnet )
# we will use efficientnetb3 from EfficientNet family.
base_model = tf.keras.applications.efficientnet.EfficientNetB7(include_top= False, weights= "imagenet", input_shape= img_shape, pooling= 'max')
# base_model.trainable = False
model = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, kernel_regularizer= regularizers.l2(l= 0.016), activity_regularizer= regularizers.l1(0.006),
                bias_regularizer= regularizers.l1(0.006), activation= 'relu'),
    Dropout(rate= 0.45, seed= 123),
    Dense(class_count, activation= 'softmax')
])

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb7 (Functional  (None, 2560)              64097687
#  )
#
#  batch_normalization (Batch  (None, 2560)              10240
#  Normalization)
#
#  dense (Dense)               (None, 256)               655616
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 64765342 (247.06 MB)
# Trainable params: 64449495 (245.86 MB)
# Non-trainable params: 315847 (1.20 MB)
# _________________________________________________________________

# %% [markdown]
# # 7| Fitting our model

# %%
batch_size = 20   # set batch size for training
epochs =  20  # number of all epochs in training

history = model.fit(x= train_gen, epochs= epochs, verbose= 1, validation_data= valid_gen, 
                    validation_steps= None, shuffle= False)
# Out:
# Epoch 1/20
# 2024-11-14 09:27:43.370467: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/efficientnetb7/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731576475.188853     112 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 809/809 [==============================] - 624s 614ms/step - loss: 6.9549 - accuracy: 0.4250 - val_loss: 4.2474 - val_accuracy: 0.5783
# Epoch 2/20
# 809/809 [==============================] - 493s 609ms/step - loss: 3.1293 - accuracy: 0.5770 - val_loss: 2.1926 - val_accuracy: 0.6256
# Epoch 3/20
# 809/809 [==============================] - 490s 606ms/step - loss: 1.7513 - accuracy: 0.6603 - val_loss: 1.5829 - val_accuracy: 0.6261
# Epoch 4/20
# 809/809 [==============================] - 490s 606ms/step - loss: 1.1850 - accuracy: 0.7425 - val_loss: 1.3907 - val_accuracy: 0.6284
# Epoch 5/20
# 809/809 [==============================] - 491s 606ms/step - loss: 0.9145 - accuracy: 0.8055 - val_loss: 1.3835 - val_accuracy: 0.6303
# Epoch 6/20
# 809/809 [==============================] - 490s 606ms/step - loss: 0.7111 - accuracy: 0.8656 - val_loss: 1.4458 - val_accuracy: 0.6045
# Epoch 7/20
# 809/809 [==============================] - 491s 606ms/step - loss: 0.6802 - accuracy: 0.8686 - val_loss: 1.5459 - val_accuracy: 0.6017
# Epoch 8/20
# 809/809 [==============================] - 491s 607ms/step - loss: 0.6064 - accuracy: 0.8930 - val_loss: 1.5345 - val_accuracy: 0.6078
# Epoch 9/20
# 809/809 [==============================] - 491s 606ms/step - loss: 0.4950 - accuracy: 0.9223 - val_loss: 1.6514 - val_accuracy: 0.6229
# Epoch 10/20
# 809/809 [==============================] - 491s 607ms/step - loss: 0.4568 - accuracy: 0.9296 - val_loss: 1.5695 - val_accuracy: 0.6196
# Epoch 11/20
# 809/809 [==============================] - 491s 607ms/step - loss: 0.4242 - accuracy: 0.9370 - val_loss: 1.6618 - val_accuracy: 0.6157
# Epoch 12/20
# 809/809 [==============================] - 491s 607ms/step - loss: 0.3639 - accuracy: 0.9556 - val_loss: 1.5925 - val_accuracy: 0.6328
# Epoch 13/20
# 809/809 [==============================] - 491s 607ms/step - loss: 0.3298 - accuracy: 0.9594 - val_loss: 1.6826 - val_accuracy: 0.6312
# Epoch 14/20
# 809/809 [==============================] - 491s 607ms/step - loss: 0.3248 - accuracy: 0.9594 - val_loss: 1.6958 - val_accuracy: 0.6224
# Epoch 15/20
# 809/809 [==============================] - 490s 606ms/step - loss: 0.3110 - accuracy: 0.9621 - val_loss: 1.7276 - val_accuracy: 0.6143
# Epoch 16/20
# 809/809 [==============================] - 490s 606ms/step - loss: 0.3143 - accuracy: 0.9595 - val_loss: 1.5916 - val_accuracy: 0.6198
# Epoch 17/20
# 809/809 [==============================] - 490s 606ms/step - loss: 0.2987 - accuracy: 0.9594 - val_loss: 1.7569 - val_accuracy: 0.6263
# Epoch 18/20
# 809/809 [==============================] - 492s 609ms/step - loss: 0.2872 - accuracy: 0.9650 - val_loss: 1.6976 - val_accuracy: 0.6410
# Epoch 19/20
# 809/809 [==============================] - 491s 607ms/step - loss: 0.2768 - accuracy: 0.9655 - val_loss: 1.7456 - val_accuracy: 0.6382
# Epoch 20/20
# 809/809 [==============================] - 490s 606ms/step - loss: 0.2418 - accuracy: 0.9750 - val_loss: 1.7738 - val_accuracy: 0.6166

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'
# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')
plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout
plt.show()

# %% [markdown]
# # 8| Evaluate the model

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Validation Loss: ", valid_score[0])
print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 359/359 [==============================] - 42s 117ms/step - loss: 0.2252 - accuracy: 0.9650
# 359/359 [==============================] - 32s 89ms/step - loss: 1.7738 - accuracy: 0.6166
# 359/359 [==============================] - 23s 63ms/step - loss: 1.7321 - accuracy: 0.6247
# Train Loss:  0.2251734584569931
# Train Accuracy:  0.965006947517395
# --------------------
# Validation Loss:  1.7737911939620972
# Validation Accuracy:  0.6165814995765686
# --------------------
# Test Loss:  1.7321109771728516
# Test Accuracy:  0.6246517896652222

# %% [markdown]
# # 9| Predictions

# %%
preds = model.predict_generator(test_gen)
y_pred = np.argmax(preds, axis=1)

# %% [markdown]
# # confusion matrix and classification report

# %%
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

# Confusion matrix
cm = confusion_matrix(test_gen.classes, y_pred)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %%
# Classification report
print(classification_report(test_gen.classes, y_pred, target_names= classes))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.57      0.58      0.57       361
#    disgusted       0.89      0.67      0.76        48
#      fearful       0.52      0.42      0.46       420
#        happy       0.81      0.76      0.78       709
#      neutral       0.53      0.64      0.58       505
#          sad       0.52      0.48      0.50       485
#    surprised       0.69      0.82      0.75       344
#
#     accuracy                           0.62      2872
#    macro avg       0.65      0.62      0.63      2872
# weighted avg       0.63      0.62      0.62      2872

# %% [markdown]
# # 10| saving the model and load it to predict

# %%
model.save("/kaggle/working/model.h5")
